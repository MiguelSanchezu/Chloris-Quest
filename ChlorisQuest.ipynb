# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 659.4/659.4 kB 9.8 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 164MB/s]

# %%
# !touch data.yaml

# %%
model.train(data = "/content/drive/MyDrive/Plant Detection.v1i.yolov8/data.yaml", epochs = 10)
# Out:
# Ultralytics YOLOv8.0.223 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/Plant Detection.v1i.yolov8/test/images" , save = True, save_txt = True)
# Out:
# image 1/186 /content/drive/MyDrive/Plant Detection.v1i.yolov8/test/images/ezgif-frame-002_jpg.rf.e39acbb2171865635d4641ed0856432a.jpg: 640x640 1 Oleander, 37.3ms
# image 2/186 /content/drive/MyDrive/Plant Detection.v1i.yolov8/test/images/ezgif-frame-003_jpg.rf.00aee6ac7106542e2618e1969e69f2dc.jpg: 640x640 1 Ficus Religiosa-Raavi-, 37.3ms
# image 3/186 /content/drive/MyDrive/Plant Detection.v1i.yolov8/test/images/ezgif-frame-004_jpg.rf.1ea01664f43560594c9d514a6ac9c2f4.jpg: 640x640 1 Calotropis, 37.2ms
# image 4/186 /content/drive/MyDrive/Plant Detection.v1i.yolov8/test/images/ezgif-frame-004_jpg.rf.6aa5a8f9e9b05a149ac20b8c35561295.jpg: 640x640 1 Ficus Religiosa-Raavi-, 37.2ms
# image 5/186 /content/drive/MyDrive/Plant Detection.v1i.yolov8/test/images/ezgif-frame-004_jpg.rf.d971e5a27633451caa2b97932bacd5e9.jpg: 640x640 1 Ficus Religiosa-Raavi-, 37.4ms
# ...
